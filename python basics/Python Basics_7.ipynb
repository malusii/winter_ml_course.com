# %% [markdown]
# ![profile.JPG](attachment:profile.JPG)
# >>>>>> An Introduction to Python Machine Learning by Dr Sibiya

# %% [markdown]
# # Running time Complexity and Data Structures

# %% [markdown]
# ![running%20time.JPG](attachment:running%20time.JPG)

# %% [markdown]
# ![datastructures.JPG](attachment:datastructures.JPG)

# %% [markdown]
# ![d1.JPG](attachment:d1.JPG)

# %% [markdown]
# ![D2.JPG](attachment:D2.JPG)

# %% [markdown]
# ![d3.JPG](attachment:d3.JPG)

# %% [markdown]
# ![d4.JPG](attachment:d4.JPG)

# %% [markdown]
# # Advanced operations in Lists

# %%
# Rememebr that arrays/lists were covered in the previous lessons.
# In this lesson we are going to cover their advanced operarions
my_list = ["boys", 1,"car"]

# %%
# The list called my_list can be updated in so many ways
# we will only cover a few of them

# %%
# Let us check what is there in the my_list list
print(my_list)
# Out:
# ['boys', 1, 'car']

# %%
# Now let us add another item/element in the my_list by using an append function
my_list.append("girls")# This will add an item/elemnt called "girls" in the last index of my_list

# %%
#Now let us check my_list after the append function was used to add the element/item "girls"
print(my_list)
# Out:
# ['boys', 1, 'car', 'girls']

# %%
# You can see that "girls" is now in the list

# %%
# Let us look another function you use to manipulate my_list
# To show a list of functions associated with a list, just press TAB button after the dot operator
my_list.remove('boys')

# %% [markdown]
# ![list%20dot%20op1.JPG](attachment:list%20dot%20op1.JPG)

# %% [markdown]
# # Exercise

# %% [markdown]
# * We only used "append" and "remove" functions in this list to explain the advanced operations of a list.
# Figure out how other functions associated with lists can be used.

# %% [markdown]
# * Figure out the code below and understand it.
# What conclusion did you make?

# %% [markdown]
# ![listexercise.JPG](attachment:listexercise.JPG)
