# %% [markdown]
# ![profile.JPG](attachment:profile.JPG)
# >>>>>> An introduction to Python for Machine Learning by Dr M.Sibiya

# %% [markdown]
# # Print Function

# %%
print("Welcome to Python course by Dr Sibiya")# This will print the information within the paranthesis within the console
# Out:
# Welcome to Python course by Dr Sibiya

# %% [markdown]
# # Commenting in Python

# %%
print("Only this information will be printed") # This will not be printed as it is the comment line
# Out:
# Only this information will be printed

# %%
""" Any information enclosed within 3 qoutation marks 
will be ragearded as multi-line comments
and therefore Python will not require the use 
single line commenting by means of # sign """
# Out:
# ' Any information enclosed within 3 qoutation marks \nwill be ragearded as multi-line comments\nand therefore Python will not require the use \nsingle line commenting by means of # sign '

# %% [markdown]
# # Data Types, Variables, Arithmetic operations and Boolean operators

# %% [markdown]
# ## Variables and Data Types

# %% [markdown]
# ![datatypes.JPG](attachment:datatypes.JPG)

# %% [markdown]
# ![datatypes2.JPG](attachment:datatypes2.JPG)

# %%
# The number_1 variable is going to be the integer data type since it stores an integer number
number_1 = 2
# The number_2 variable is going to be the float data type since it stores a floating number
number_2 = 3.91
# The string_1 variable is going to be the integer data type since it stores a string
string_1 = "Python basics by Dr Sibiya"

# %%
#Now check the data type of the above variables
print(type(number_1))
# Out:
# <class 'int'>

# %%
print(type(number_2))
# Out:
# <class 'float'>

# %%
print(type(string_1))
# Out:
# <class 'str'>

# %%
# Alternatively you can check the data types without using the print function. 
#Please take note that is only possible in Jupyter note book IDE
type(number_1)
# Out:
# int

# %%
type(number_2)
# Out:
# float

# %%
type(string_1)
# Out:
# str

# %% [markdown]
# ## Arithemetic operators

# %%
# Multpier operator
print(number_1 * number_1) # the contents of number1 are multiplied and the answer is printed
# Out:
# 4

# %%
# The Addition operator
number_3 = number_1 + number_1 # The contents of number 2 are added together and assigned to a new variable called number_3

# %%
print(number_3)
# Out:
# 4

# %%
# The division operator that returns a whole number when the dividing number is a factor, otherwise a floation number if not

number_1/number_3 # In Jupyter IDE you may not use the print function because the cell automatically return the computed operation
# Out:
# 0.5

# %%
# This can still work 
print(number_1/number_3)
# Out:
# 0.5

# %%
number_4 = 5 # Assigns the value of 5 to a new variable called number_4

# %%
number_5 = 11 % number_4 # perfom the mudulus operation

# %%
print(number_5) # print the result of the modulo oeration. The modulo operation returns the remainder of the division operation
# Out:
# 1

# %%
number_1//number_3 # Floor division operation
# Out:
# 0

# %%
# Floor division operation closely observed
print(5//3) # It can be seen that the floor division operation only returns the whole number
# Out:
# 1

# %%
# Exponentiation
print(3**2) # In simple terms this is 3 to the pwoer 2
# Out:
# 9

# %%
(3**2)**2 # Remember that @in Jupyter IDE, the computed results may be displayed even without using the print function.
# Out:
# 81

# %% [markdown]
# ## Boolean operators

# %%
print(3<1)# Since this logical statement is False as 3 is not smaller than 1, the False Boolean value is returned
# Out:
# False

# %%
boolean_1 = (5>1) # This stores a True Boolean value to a variable called boolean_1

# %%
print(boolean_1) # print the value stored in boolean_1
# Out:
# True

# %%
type(boolean_1) # Checks the data type of boolean_1 variable
# Out:
# bool

# %%
# Remember you can also use the print function to check the type of the variable
print(type(boolean_1))
# Out:
# <class 'bool'>

# %% [markdown]
# # Exerecises

# %% [markdown]
# * Create different variables and check their data types after the information of your choice has been stored in them.
# * The subtraction operator is not mentioned in this lesson. Figure out how it can be used by means of examples

# %% [markdown]
# See you in the next lesson
